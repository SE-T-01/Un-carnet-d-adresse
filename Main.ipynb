# %%
import re
#%run contact.ipynb
#import AdressBook
import contact
#import AdressBook
from AddressBook import AddressBook
from contact import Contact
#from AdressBook import AdressBook

# %%
def AfficheOption():
    print("1 Ajouter Contact ")
    print("2 Supprimer Contact ")
    print("3 Afficher Contact ")
    print("4 Afficher Tous le contact ")
    print("5 Quitter")

# %%
pattern = r'^[\w\.-]+@[\w\.-]+\.\w+$'
AfficheOption()
# Out:
# 1 Ajouter Contact
# 2 Supprimer Contact
# 3 Afficher Contact
# 4 Afficher Tous le contact
# 5 Quitter

# %%
rep=AddressBook()
while True:
    AfficheOption()
    Entree=int(input("Choisir l'opération que vous voulez :"))
    if Entree ==1:
        Nom=input("Saisez le nom")
        assert isinstance(Nom,str) and len(Nom) !=0,"Numéro Invalid"
        Tel=input("Saisiez le numéro de téléphone")
        assert isinstance(Tel,str) and Tel.isdigit() and len(Tel)>=10 and (Tel.startswith("06") or Tel.startswith("07")) ,"Numéro de téléphone invalide"
        Email=input("Saisez l'email")
        assert isinstance(Email,str) and re.match(pattern, Email) ,"Email non valid"
        c1=Contact(Nom,Tel,Email)
        rep.AddContact(c1)
    elif Entree==2:
        Nom=input("Saisez le nom")
        assert isinstance(Nom,str) and len(Nom) !=0,"Numéro Invalid"
        rep.RemoveContact(Nom)
    elif Entree==3:
        Nom=input("Saisez le nom")
        assert isinstance(Nom,str) and len(Nom) !=0,"Numéro Invalid"
        rep.desplayContact(Nom)
    elif Entree==4:
        print("Affichage de Tous contact")
        rep.afficher_fichier()
    elif Entree==5:
         print("Sortie de Système!!")
         break
    else:
        print("Choix Invalid")
# Out:
# 1 Ajouter Contact
# 2 Supprimer Contact
# 3 Afficher Contact
# 4 Afficher Tous le contact
# 5 Quitter
# Choisir l'opération que vous voulez : 4
# Affichage de Tous contact
# Ali   0656457677   ali@gmail.com
# aaaa   0645343465   aa@gmail.com
# 1 Ajouter Contact
# 2 Supprimer Contact
# 3 Afficher Contact
# 4 Afficher Tous le contact
# 5 Quitter
# Choisir l'opération que vous voulez : 5
# Sortie de Système!!

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[7], line 15
#      12     root.mainloop()
#      14 if __name__ == "__main__":
# ---> 15     main()
#
# Cell In[7], line 9, in main()
#       6 root = tk.Tk()
#       8 # Créer l'application (qui construit toute l'interface)
# ----> 9 app = ContactApp(root)
#      11 # Lancer la boucle principale
#      12 root.mainloop()
#
# File ~\Saved Games\interface.py:14, in ContactApp.__init__(self, root)
#      11 self.root.resizable(True, True)
#      13 # Carnet d'adresses
# ---> 14 self.carnet = AddressBook("contacts.txt")
#      16 # Création de l'interface
#      17 self.create_widgets()
#
# File ~\Saved Games\AddressBook.py:38, in AddressBook.__init__(self, fich)
#      36     open(self.fich,"w").close()
#      37 else:#Charger les contacts existants (si fichier existe)
# ---> 38     self.charger()
#
# File ~\Saved Games\AddressBook.py:42, in AddressBook.charger(self)
#      40 """Lit le fichier et remplit self.book"""
#      41 with open(self.fich, 'r') as f:
# ---> 42     for ligne in f:
#      43         ligne = ligne.strip()
#      44         if ligne:
#
# File ~\anaconda3\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 3826: character maps to <undefined>
